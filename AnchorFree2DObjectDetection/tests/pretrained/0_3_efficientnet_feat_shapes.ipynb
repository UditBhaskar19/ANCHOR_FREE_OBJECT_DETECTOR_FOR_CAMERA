# %%
from torchvision import models
import sys
sys.path.append('../..')
from modules.pretrained.utils_backbone_cfg import (
    display_node_names_and_feature_map_shapes,
    display_feature_map_shapes_for_specific_node_names)
device = 'cuda'

# %% [markdown]
# ## EfficientNet B0

# %%
weights = "IMAGENET1K_V1"
model = models.efficientnet_b0(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [32, 128, 128]
# features.1.0.block.0 --------------- [32, 128, 128]
# features.1.0.block.1 --------------- [32, 128, 128]
# features.1.0.block.2 --------------- [16, 128, 128]
# features.2.0.block.0 --------------- [96, 128, 128]
# features.2.0.block.1 --------------- [96, 64, 64]
# features.2.0.block.2 --------------- [96, 64, 64]
# features.2.0.block.3 --------------- [24, 64, 64]
# features.2.1.block.0 --------------- [144, 64, 64]
# features.2.1.block.1 --------------- [144, 64, 64]
# features.2.1.block.2 --------------- [144, 64, 64]
# features.2.1.block.3 --------------- [24, 64, 64]
# features.2.1.stochastic_depth ------ [24, 64, 64]
# features.2.1.add ------------------- [24, 64, 64]
# features.3.0.block.0 --------------- [144, 64, 64]
# features.3.0.block.1 --------------- [144, 32, 32]
# features.3.0.block.2 --------------- [144, 32, 32]
# features.3.0.block.3 --------------- [40, 32, 32]
# ...

# %%
efficientnet_b0_return_nodes = ('features.2.1.add', 
                                'features.3.1.add', 
                                'features.5.2.add',
                                'features.7.0.block.3')
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_b0_return_nodes)
# Out:
# features.2.1.add ------------------- [24, 64, 64]
# features.3.1.add ------------------- [40, 32, 32]
# features.5.2.add ------------------- [112, 16, 16]
# features.7.0.block.3 --------------- [320, 8, 8]

# %% [markdown]
# ## EfficientNet B1

# %%
weights = "IMAGENET1K_V2"
model = models.efficientnet_b1(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [32, 128, 128]
# features.1.0.block.0 --------------- [32, 128, 128]
# features.1.0.block.1 --------------- [32, 128, 128]
# features.1.0.block.2 --------------- [16, 128, 128]
# features.1.1.block.0 --------------- [16, 128, 128]
# features.1.1.block.1 --------------- [16, 128, 128]
# features.1.1.block.2 --------------- [16, 128, 128]
# features.1.1.stochastic_depth ------ [16, 128, 128]
# features.1.1.add ------------------- [16, 128, 128]
# features.2.0.block.0 --------------- [96, 128, 128]
# features.2.0.block.1 --------------- [96, 64, 64]
# features.2.0.block.2 --------------- [96, 64, 64]
# features.2.0.block.3 --------------- [24, 64, 64]
# features.2.1.block.0 --------------- [144, 64, 64]
# features.2.1.block.1 --------------- [144, 64, 64]
# features.2.1.block.2 --------------- [144, 64, 64]
# features.2.1.block.3 --------------- [24, 64, 64]
# features.2.1.stochastic_depth ------ [24, 64, 64]
# ...

# %%
efficientnet_b1_return_nodes = ('features.2.2.add', 
                                'features.3.2.add', 
                                'features.5.3.add',
                                'features.7.1.add')
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_b1_return_nodes)
# Out:
# features.2.2.add ------------------- [24, 64, 64]
# features.3.2.add ------------------- [40, 32, 32]
# features.5.3.add ------------------- [112, 16, 16]
# features.7.1.add ------------------- [320, 8, 8]

# %% [markdown]
# ## EfficientNet B2

# %%
weights = "IMAGENET1K_V1"
model = models.efficientnet_b2(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [32, 128, 128]
# features.1.0.block.0 --------------- [32, 128, 128]
# features.1.0.block.1 --------------- [32, 128, 128]
# features.1.0.block.2 --------------- [16, 128, 128]
# features.1.1.block.0 --------------- [16, 128, 128]
# features.1.1.block.1 --------------- [16, 128, 128]
# features.1.1.block.2 --------------- [16, 128, 128]
# features.1.1.stochastic_depth ------ [16, 128, 128]
# features.1.1.add ------------------- [16, 128, 128]
# features.2.0.block.0 --------------- [96, 128, 128]
# features.2.0.block.1 --------------- [96, 64, 64]
# features.2.0.block.2 --------------- [96, 64, 64]
# features.2.0.block.3 --------------- [24, 64, 64]
# features.2.1.block.0 --------------- [144, 64, 64]
# features.2.1.block.1 --------------- [144, 64, 64]
# features.2.1.block.2 --------------- [144, 64, 64]
# features.2.1.block.3 --------------- [24, 64, 64]
# features.2.1.stochastic_depth ------ [24, 64, 64]
# ...

# %%
efficientnet_b2_return_nodes = ('features.2.2.add', 
                                'features.3.2.add', 
                                'features.5.3.add',
                                'features.7.1.add')
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_b2_return_nodes)
# Out:
# features.2.2.add ------------------- [24, 64, 64]
# features.3.2.add ------------------- [48, 32, 32]
# features.5.3.add ------------------- [120, 16, 16]
# features.7.1.add ------------------- [352, 8, 8]

# %% [markdown]
# ## EfficientNet B3

# %%
weights = "IMAGENET1K_V1"
model = models.efficientnet_b3(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [40, 128, 128]
# features.1.0.block.0 --------------- [40, 128, 128]
# features.1.0.block.1 --------------- [40, 128, 128]
# features.1.0.block.2 --------------- [24, 128, 128]
# features.1.1.block.0 --------------- [24, 128, 128]
# features.1.1.block.1 --------------- [24, 128, 128]
# features.1.1.block.2 --------------- [24, 128, 128]
# features.1.1.stochastic_depth ------ [24, 128, 128]
# features.1.1.add ------------------- [24, 128, 128]
# features.2.0.block.0 --------------- [144, 128, 128]
# features.2.0.block.1 --------------- [144, 64, 64]
# features.2.0.block.2 --------------- [144, 64, 64]
# features.2.0.block.3 --------------- [32, 64, 64]
# features.2.1.block.0 --------------- [192, 64, 64]
# features.2.1.block.1 --------------- [192, 64, 64]
# features.2.1.block.2 --------------- [192, 64, 64]
# features.2.1.block.3 --------------- [32, 64, 64]
# features.2.1.stochastic_depth ------ [32, 64, 64]
# ...

# %%
efficientnet_b3_return_nodes = ('features.2.2.add', 
                                'features.3.2.add', 
                                'features.5.4.add',
                                'features.7.1.add')
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_b3_return_nodes)
# Out:
# features.2.2.add ------------------- [32, 64, 64]
# features.3.2.add ------------------- [48, 32, 32]
# features.5.4.add ------------------- [136, 16, 16]
# features.7.1.add ------------------- [384, 8, 8]

# %% [markdown]
# ## EfficientNet B4

# %%
weights = "IMAGENET1K_V1"
model = models.efficientnet_b4(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [48, 128, 128]
# features.1.0.block.0 --------------- [48, 128, 128]
# features.1.0.block.1 --------------- [48, 128, 128]
# features.1.0.block.2 --------------- [24, 128, 128]
# features.1.1.block.0 --------------- [24, 128, 128]
# features.1.1.block.1 --------------- [24, 128, 128]
# features.1.1.block.2 --------------- [24, 128, 128]
# features.1.1.stochastic_depth ------ [24, 128, 128]
# features.1.1.add ------------------- [24, 128, 128]
# features.2.0.block.0 --------------- [144, 128, 128]
# features.2.0.block.1 --------------- [144, 64, 64]
# features.2.0.block.2 --------------- [144, 64, 64]
# features.2.0.block.3 --------------- [32, 64, 64]
# features.2.1.block.0 --------------- [192, 64, 64]
# features.2.1.block.1 --------------- [192, 64, 64]
# features.2.1.block.2 --------------- [192, 64, 64]
# features.2.1.block.3 --------------- [32, 64, 64]
# features.2.1.stochastic_depth ------ [32, 64, 64]
# ...

# %%
efficientnet_b4_return_nodes = ('features.2.3.add', 
                                'features.3.3.add', 
                                'features.5.5.add',
                                'features.7.1.add')
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_b4_return_nodes)
# Out:
# features.2.3.add ------------------- [32, 64, 64]
# features.3.3.add ------------------- [56, 32, 32]
# features.5.5.add ------------------- [160, 16, 16]
# features.7.1.add ------------------- [448, 8, 8]

# %% [markdown]
# ## EfficientNet B5

# %%
weights = "IMAGENET1K_V1"
model = models.efficientnet_b5(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [48, 128, 128]
# features.1.0.block.0 --------------- [48, 128, 128]
# features.1.0.block.1 --------------- [48, 128, 128]
# features.1.0.block.2 --------------- [24, 128, 128]
# features.1.1.block.0 --------------- [24, 128, 128]
# features.1.1.block.1 --------------- [24, 128, 128]
# features.1.1.block.2 --------------- [24, 128, 128]
# features.1.1.stochastic_depth ------ [24, 128, 128]
# features.1.1.add ------------------- [24, 128, 128]
# features.1.2.block.0 --------------- [24, 128, 128]
# features.1.2.block.1 --------------- [24, 128, 128]
# features.1.2.block.2 --------------- [24, 128, 128]
# features.1.2.stochastic_depth ------ [24, 128, 128]
# features.1.2.add ------------------- [24, 128, 128]
# features.2.0.block.0 --------------- [144, 128, 128]
# features.2.0.block.1 --------------- [144, 64, 64]
# features.2.0.block.2 --------------- [144, 64, 64]
# features.2.0.block.3 --------------- [40, 64, 64]
# ...

# %%
efficientnet_b5_return_nodes = ('features.2.4.add', 
                                'features.3.4.add', 
                                'features.5.6.add',
                                'features.7.2.add') 
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_b5_return_nodes)
# Out:
# features.2.4.add ------------------- [40, 64, 64]
# features.3.4.add ------------------- [64, 32, 32]
# features.5.6.add ------------------- [176, 16, 16]
# features.7.2.add ------------------- [512, 8, 8]

# %% [markdown]
# ## EfficientNet B6

# %%
weights = "IMAGENET1K_V1"
model = models.efficientnet_b6(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [56, 128, 128]
# features.1.0.block.0 --------------- [56, 128, 128]
# features.1.0.block.1 --------------- [56, 128, 128]
# features.1.0.block.2 --------------- [32, 128, 128]
# features.1.1.block.0 --------------- [32, 128, 128]
# features.1.1.block.1 --------------- [32, 128, 128]
# features.1.1.block.2 --------------- [32, 128, 128]
# features.1.1.stochastic_depth ------ [32, 128, 128]
# features.1.1.add ------------------- [32, 128, 128]
# features.1.2.block.0 --------------- [32, 128, 128]
# features.1.2.block.1 --------------- [32, 128, 128]
# features.1.2.block.2 --------------- [32, 128, 128]
# features.1.2.stochastic_depth ------ [32, 128, 128]
# features.1.2.add ------------------- [32, 128, 128]
# features.2.0.block.0 --------------- [192, 128, 128]
# features.2.0.block.1 --------------- [192, 64, 64]
# features.2.0.block.2 --------------- [192, 64, 64]
# features.2.0.block.3 --------------- [40, 64, 64]
# ...

# %%
efficientnet_b6_return_nodes = ('features.2.5.add', 
                                'features.3.5.add', 
                                'features.5.7.add',
                                'features.7.2.add')
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_b6_return_nodes)
# Out:
# features.2.5.add ------------------- [40, 64, 64]
# features.3.5.add ------------------- [72, 32, 32]
# features.5.7.add ------------------- [200, 16, 16]
# features.7.2.add ------------------- [576, 8, 8]

# %% [markdown]
# ## EfficientNet B7

# %%
weights = "IMAGENET1K_V1"
model = models.efficientnet_b7(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [64, 128, 128]
# features.1.0.block.0 --------------- [64, 128, 128]
# features.1.0.block.1 --------------- [64, 128, 128]
# features.1.0.block.2 --------------- [32, 128, 128]
# features.1.1.block.0 --------------- [32, 128, 128]
# features.1.1.block.1 --------------- [32, 128, 128]
# features.1.1.block.2 --------------- [32, 128, 128]
# features.1.1.stochastic_depth ------ [32, 128, 128]
# features.1.1.add ------------------- [32, 128, 128]
# features.1.2.block.0 --------------- [32, 128, 128]
# features.1.2.block.1 --------------- [32, 128, 128]
# features.1.2.block.2 --------------- [32, 128, 128]
# features.1.2.stochastic_depth ------ [32, 128, 128]
# features.1.2.add ------------------- [32, 128, 128]
# features.1.3.block.0 --------------- [32, 128, 128]
# features.1.3.block.1 --------------- [32, 128, 128]
# features.1.3.block.2 --------------- [32, 128, 128]
# features.1.3.stochastic_depth ------ [32, 128, 128]
# ...

# %%
efficientnet_b7_return_nodes = ('features.2.6.add', 
                                'features.3.6.add', 
                                'features.5.9.add',
                                'features.7.3.add')
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_b7_return_nodes)
# Out:
# features.2.6.add ------------------- [48, 64, 64]
# features.3.6.add ------------------- [80, 32, 32]
# features.5.9.add ------------------- [224, 16, 16]
# features.7.3.add ------------------- [640, 8, 8]

# %% [markdown]
# ## Efficientnet_v2_s

# %%
weights = "IMAGENET1K_V1"
model = models.efficientnet_v2_s(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [24, 128, 128]
# features.1.0.block.0 --------------- [24, 128, 128]
# features.1.0.stochastic_depth ------ [24, 128, 128]
# features.1.0.add ------------------- [24, 128, 128]
# features.1.1.block.0 --------------- [24, 128, 128]
# features.1.1.stochastic_depth ------ [24, 128, 128]
# features.1.1.add ------------------- [24, 128, 128]
# features.2.0.block.0 --------------- [96, 64, 64]
# features.2.0.block.1 --------------- [48, 64, 64]
# features.2.1.block.0 --------------- [192, 64, 64]
# features.2.1.block.1 --------------- [48, 64, 64]
# features.2.1.stochastic_depth ------ [48, 64, 64]
# features.2.1.add ------------------- [48, 64, 64]
# features.2.2.block.0 --------------- [192, 64, 64]
# features.2.2.block.1 --------------- [48, 64, 64]
# features.2.2.stochastic_depth ------ [48, 64, 64]
# features.2.2.add ------------------- [48, 64, 64]
# features.2.3.block.0 --------------- [192, 64, 64]
# ...

# %%
efficientnet_v2_s_return_nodes = ('features.2.3.add', 
                                  'features.3.3.add', 
                                  'features.5.8.add',
                                  'features.6.14.add')
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_v2_s_return_nodes)
# Out:
# features.2.3.add ------------------- [48, 64, 64]
# features.3.3.add ------------------- [64, 32, 32]
# features.5.8.add ------------------- [160, 16, 16]
# features.6.14.add ------------------ [256, 8, 8]

# %% [markdown]
# ## Efficientnet_v2_m

# %%
weights = "IMAGENET1K_V1"
model = models.efficientnet_v2_m(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [24, 128, 128]
# features.1.0.block.0 --------------- [24, 128, 128]
# features.1.0.stochastic_depth ------ [24, 128, 128]
# features.1.0.add ------------------- [24, 128, 128]
# features.1.1.block.0 --------------- [24, 128, 128]
# features.1.1.stochastic_depth ------ [24, 128, 128]
# features.1.1.add ------------------- [24, 128, 128]
# features.1.2.block.0 --------------- [24, 128, 128]
# features.1.2.stochastic_depth ------ [24, 128, 128]
# features.1.2.add ------------------- [24, 128, 128]
# features.2.0.block.0 --------------- [96, 64, 64]
# features.2.0.block.1 --------------- [48, 64, 64]
# features.2.1.block.0 --------------- [192, 64, 64]
# features.2.1.block.1 --------------- [48, 64, 64]
# features.2.1.stochastic_depth ------ [48, 64, 64]
# features.2.1.add ------------------- [48, 64, 64]
# features.2.2.block.0 --------------- [192, 64, 64]
# features.2.2.block.1 --------------- [48, 64, 64]
# ...

# %%
efficientnet_v2_m_return_nodes = ('features.2.4.add', 
                                  'features.3.4.add', 
                                  'features.5.13.add',
                                  'features.7.4.add')
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_v2_m_return_nodes)
# Out:
# features.2.4.add ------------------- [48, 64, 64]
# features.3.4.add ------------------- [80, 32, 32]
# features.5.13.add ------------------ [176, 16, 16]
# features.7.4.add ------------------- [512, 8, 8]

# %% [markdown]
# ## Efficientnet_v2_l

# %%
weights = "IMAGENET1K_V1"
model = models.efficientnet_v2_l(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [32, 128, 128]
# features.1.0.block.0 --------------- [32, 128, 128]
# features.1.0.stochastic_depth ------ [32, 128, 128]
# features.1.0.add ------------------- [32, 128, 128]
# features.1.1.block.0 --------------- [32, 128, 128]
# features.1.1.stochastic_depth ------ [32, 128, 128]
# features.1.1.add ------------------- [32, 128, 128]
# features.1.2.block.0 --------------- [32, 128, 128]
# features.1.2.stochastic_depth ------ [32, 128, 128]
# features.1.2.add ------------------- [32, 128, 128]
# features.1.3.block.0 --------------- [32, 128, 128]
# features.1.3.stochastic_depth ------ [32, 128, 128]
# features.1.3.add ------------------- [32, 128, 128]
# features.2.0.block.0 --------------- [128, 64, 64]
# features.2.0.block.1 --------------- [64, 64, 64]
# features.2.1.block.0 --------------- [256, 64, 64]
# features.2.1.block.1 --------------- [64, 64, 64]
# features.2.1.stochastic_depth ------ [64, 64, 64]
# ...

# %%
efficientnet_v2_l_return_nodes = ('features.2.6.add', 
                                  'features.3.6.add', 
                                  'features.5.18.add',
                                  'features.7.6.add')
display_feature_map_shapes_for_specific_node_names(device, model, efficientnet_v2_l_return_nodes)
# Out:
# features.2.6.add ------------------- [64, 64, 64]
# features.3.6.add ------------------- [96, 32, 32]
# features.5.18.add ------------------ [224, 16, 16]
# features.7.6.add ------------------- [640, 8, 8]

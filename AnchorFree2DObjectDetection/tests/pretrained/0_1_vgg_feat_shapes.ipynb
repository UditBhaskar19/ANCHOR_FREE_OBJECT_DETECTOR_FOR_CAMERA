# %%
from torchvision import models
import sys
sys.path.append('../..')
from modules.pretrained.utils_backbone_cfg import (
    display_node_names_and_feature_map_shapes,
    display_feature_map_shapes_for_specific_node_names)
device = 'cuda'

# %% [markdown]
# ## VGG11

# %%
weights = "IMAGENET1K_V1"
model = models.vgg11(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [64, 256, 256]
# features.1 ------------------------- [64, 256, 256]
# features.2 ------------------------- [64, 128, 128]
# features.3 ------------------------- [128, 128, 128]
# features.4 ------------------------- [128, 128, 128]
# features.5 ------------------------- [128, 64, 64]
# features.6 ------------------------- [256, 64, 64]
# features.7 ------------------------- [256, 64, 64]
# features.8 ------------------------- [256, 64, 64]
# features.9 ------------------------- [256, 64, 64]
# features.10 ------------------------ [256, 32, 32]
# features.11 ------------------------ [512, 32, 32]
# features.12 ------------------------ [512, 32, 32]
# features.13 ------------------------ [512, 32, 32]
# features.14 ------------------------ [512, 32, 32]
# features.15 ------------------------ [512, 16, 16]
# features.16 ------------------------ [512, 16, 16]
# features.17 ------------------------ [512, 16, 16]
# ...

# %%
vgg11_return_nodes = ('features.4', 
                      'features.9', 
                      'features.14',
                      'features.19')
display_feature_map_shapes_for_specific_node_names(device, model, vgg11_return_nodes)
# Out:
# features.4 ------------------------- [128, 128, 128]
# features.9 ------------------------- [256, 64, 64]
# features.14 ------------------------ [512, 32, 32]
# features.19 ------------------------ [512, 16, 16]

# %% [markdown]
# ## VGG11_BN

# %%
weights = "IMAGENET1K_V1"
model = models.vgg11_bn(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [64, 256, 256]
# features.1 ------------------------- [64, 256, 256]
# features.2 ------------------------- [64, 256, 256]
# features.3 ------------------------- [64, 128, 128]
# features.4 ------------------------- [128, 128, 128]
# features.5 ------------------------- [128, 128, 128]
# features.6 ------------------------- [128, 128, 128]
# features.7 ------------------------- [128, 64, 64]
# features.8 ------------------------- [256, 64, 64]
# features.9 ------------------------- [256, 64, 64]
# features.10 ------------------------ [256, 64, 64]
# features.11 ------------------------ [256, 64, 64]
# features.12 ------------------------ [256, 64, 64]
# features.13 ------------------------ [256, 64, 64]
# features.14 ------------------------ [256, 32, 32]
# features.15 ------------------------ [512, 32, 32]
# features.16 ------------------------ [512, 32, 32]
# features.17 ------------------------ [512, 32, 32]
# ...

# %%
vgg11_bn_return_nodes = ('features.6', 
                         'features.13', 
                         'features.20',
                         'features.27')
display_feature_map_shapes_for_specific_node_names(device, model, vgg11_bn_return_nodes)
# Out:
# features.6 ------------------------- [128, 128, 128]
# features.13 ------------------------ [256, 64, 64]
# features.20 ------------------------ [512, 32, 32]
# features.27 ------------------------ [512, 16, 16]

# %% [markdown]
# ## VGG13

# %%
weights = "IMAGENET1K_V1"
model = models.vgg13(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [64, 256, 256]
# features.1 ------------------------- [64, 256, 256]
# features.2 ------------------------- [64, 256, 256]
# features.3 ------------------------- [64, 256, 256]
# features.4 ------------------------- [64, 128, 128]
# features.5 ------------------------- [128, 128, 128]
# features.6 ------------------------- [128, 128, 128]
# features.7 ------------------------- [128, 128, 128]
# features.8 ------------------------- [128, 128, 128]
# features.9 ------------------------- [128, 64, 64]
# features.10 ------------------------ [256, 64, 64]
# features.11 ------------------------ [256, 64, 64]
# features.12 ------------------------ [256, 64, 64]
# features.13 ------------------------ [256, 64, 64]
# features.14 ------------------------ [256, 32, 32]
# features.15 ------------------------ [512, 32, 32]
# features.16 ------------------------ [512, 32, 32]
# features.17 ------------------------ [512, 32, 32]
# ...

# %%
vgg13_return_nodes = ('features.8', 
                      'features.13', 
                      'features.18',
                      'features.23')
display_feature_map_shapes_for_specific_node_names(device, model, vgg13_return_nodes)
# Out:
# features.8 ------------------------- [128, 128, 128]
# features.13 ------------------------ [256, 64, 64]
# features.18 ------------------------ [512, 32, 32]
# features.23 ------------------------ [512, 16, 16]

# %% [markdown]
# ## VGG13_BN

# %%
weights = "IMAGENET1K_V1"
model = models.vgg13_bn(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [64, 256, 256]
# features.1 ------------------------- [64, 256, 256]
# features.2 ------------------------- [64, 256, 256]
# features.3 ------------------------- [64, 256, 256]
# features.4 ------------------------- [64, 256, 256]
# features.5 ------------------------- [64, 256, 256]
# features.6 ------------------------- [64, 128, 128]
# features.7 ------------------------- [128, 128, 128]
# features.8 ------------------------- [128, 128, 128]
# features.9 ------------------------- [128, 128, 128]
# features.10 ------------------------ [128, 128, 128]
# features.11 ------------------------ [128, 128, 128]
# features.12 ------------------------ [128, 128, 128]
# features.13 ------------------------ [128, 64, 64]
# features.14 ------------------------ [256, 64, 64]
# features.15 ------------------------ [256, 64, 64]
# features.16 ------------------------ [256, 64, 64]
# features.17 ------------------------ [256, 64, 64]
# ...

# %%
vgg13_bn_return_nodes = ('features.12', 
                         'features.19', 
                         'features.26',
                         'features.33')
display_feature_map_shapes_for_specific_node_names(device, model, vgg13_bn_return_nodes)
# Out:
# features.12 ------------------------ [128, 128, 128]
# features.19 ------------------------ [256, 64, 64]
# features.26 ------------------------ [512, 32, 32]
# features.33 ------------------------ [512, 16, 16]

# %% [markdown]
# ## VGG16

# %%
weights = "IMAGENET1K_V1"
model = models.vgg16(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [64, 256, 256]
# features.1 ------------------------- [64, 256, 256]
# features.2 ------------------------- [64, 256, 256]
# features.3 ------------------------- [64, 256, 256]
# features.4 ------------------------- [64, 128, 128]
# features.5 ------------------------- [128, 128, 128]
# features.6 ------------------------- [128, 128, 128]
# features.7 ------------------------- [128, 128, 128]
# features.8 ------------------------- [128, 128, 128]
# features.9 ------------------------- [128, 64, 64]
# features.10 ------------------------ [256, 64, 64]
# features.11 ------------------------ [256, 64, 64]
# features.12 ------------------------ [256, 64, 64]
# features.13 ------------------------ [256, 64, 64]
# features.14 ------------------------ [256, 64, 64]
# features.15 ------------------------ [256, 64, 64]
# features.16 ------------------------ [256, 32, 32]
# features.17 ------------------------ [512, 32, 32]
# ...

# %%
vgg16_return_nodes = ('features.4', 
                      'features.9', 
                      'features.14',
                      'features.19')
display_feature_map_shapes_for_specific_node_names(device, model, vgg16_return_nodes)
# Out:
# features.4 ------------------------- [64, 128, 128]
# features.9 ------------------------- [128, 64, 64]
# features.14 ------------------------ [256, 64, 64]
# features.19 ------------------------ [512, 32, 32]

# %% [markdown]
# ## VGG16_BN

# %%
weights = "IMAGENET1K_V1"
model = models.vgg16_bn(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [64, 256, 256]
# features.1 ------------------------- [64, 256, 256]
# features.2 ------------------------- [64, 256, 256]
# features.3 ------------------------- [64, 256, 256]
# features.4 ------------------------- [64, 256, 256]
# features.5 ------------------------- [64, 256, 256]
# features.6 ------------------------- [64, 128, 128]
# features.7 ------------------------- [128, 128, 128]
# features.8 ------------------------- [128, 128, 128]
# features.9 ------------------------- [128, 128, 128]
# features.10 ------------------------ [128, 128, 128]
# features.11 ------------------------ [128, 128, 128]
# features.12 ------------------------ [128, 128, 128]
# features.13 ------------------------ [128, 64, 64]
# features.14 ------------------------ [256, 64, 64]
# features.15 ------------------------ [256, 64, 64]
# features.16 ------------------------ [256, 64, 64]
# features.17 ------------------------ [256, 64, 64]
# ...

# %%
vgg16_bn_return_nodes = ('features.12', 
                         'features.22', 
                         'features.32',
                         'features.42')
display_feature_map_shapes_for_specific_node_names(device, model, vgg16_bn_return_nodes)
# Out:
# features.12 ------------------------ [128, 128, 128]
# features.22 ------------------------ [256, 64, 64]
# features.32 ------------------------ [512, 32, 32]
# features.42 ------------------------ [512, 16, 16]

# %% [markdown]
# ## VGG19

# %%
weights = "IMAGENET1K_V1"
model = models.vgg19(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [64, 256, 256]
# features.1 ------------------------- [64, 256, 256]
# features.2 ------------------------- [64, 256, 256]
# features.3 ------------------------- [64, 256, 256]
# features.4 ------------------------- [64, 128, 128]
# features.5 ------------------------- [128, 128, 128]
# features.6 ------------------------- [128, 128, 128]
# features.7 ------------------------- [128, 128, 128]
# features.8 ------------------------- [128, 128, 128]
# features.9 ------------------------- [128, 64, 64]
# features.10 ------------------------ [256, 64, 64]
# features.11 ------------------------ [256, 64, 64]
# features.12 ------------------------ [256, 64, 64]
# features.13 ------------------------ [256, 64, 64]
# features.14 ------------------------ [256, 64, 64]
# features.15 ------------------------ [256, 64, 64]
# features.16 ------------------------ [256, 64, 64]
# features.17 ------------------------ [256, 64, 64]
# ...

# %%
vgg19_return_nodes = ('features.8', 
                      'features.17', 
                      'features.26',
                      'features.35')
display_feature_map_shapes_for_specific_node_names(device, model, vgg19_return_nodes)
# Out:
# features.8 ------------------------- [128, 128, 128]
# features.17 ------------------------ [256, 64, 64]
# features.26 ------------------------ [512, 32, 32]
# features.35 ------------------------ [512, 16, 16]

# %% [markdown]
# ## VGG19_BN

# %%
weights = "IMAGENET1K_V1"
model = models.vgg19_bn(weights=weights)
display_node_names_and_feature_map_shapes(device, model)
# Out:
# features.0 ------------------------- [64, 256, 256]
# features.1 ------------------------- [64, 256, 256]
# features.2 ------------------------- [64, 256, 256]
# features.3 ------------------------- [64, 256, 256]
# features.4 ------------------------- [64, 256, 256]
# features.5 ------------------------- [64, 256, 256]
# features.6 ------------------------- [64, 128, 128]
# features.7 ------------------------- [128, 128, 128]
# features.8 ------------------------- [128, 128, 128]
# features.9 ------------------------- [128, 128, 128]
# features.10 ------------------------ [128, 128, 128]
# features.11 ------------------------ [128, 128, 128]
# features.12 ------------------------ [128, 128, 128]
# features.13 ------------------------ [128, 64, 64]
# features.14 ------------------------ [256, 64, 64]
# features.15 ------------------------ [256, 64, 64]
# features.16 ------------------------ [256, 64, 64]
# features.17 ------------------------ [256, 64, 64]
# ...

# %%
vgg19_bn_return_nodes = ('features.12', 
                         'features.25', 
                         'features.38',
                         'features.51')
display_feature_map_shapes_for_specific_node_names(device, model, vgg19_bn_return_nodes)
# Out:
# features.12 ------------------------ [128, 128, 128]
# features.25 ------------------------ [256, 64, 64]
# features.38 ------------------------ [512, 32, 32]
# features.51 ------------------------ [512, 16, 16]
